# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd

from src.inventory.preprocessing import *
from src.inventory.optimization import *
from src.inventory.evaluation import *
from src.inventory.visualization import *

# %%
df = pd.read_csv(
    PROJECT_ROOT/"data"/"processed"/"online_retail_processed.csv",
    parse_dates=["InvoiceDate"]
)

# %%
inventory = prepare_inventory_data(df)

# %%
inventory = abc_analysis(inventory)

# %%
summary = inventory_summary(inventory)

print(summary)
# Out:
# {'Total Products': 6570, 'Total Revenue': np.float64(19014209.837999996), 'Total Quantity Sold': np.int64(10484017), 'Average Revenue': np.float64(2894.095865753424), 'Average Quantity': np.float64(1595.7407914764078), 'Category A Products': np.int64(1105), 'Category B Products': np.int64(1204), 'Category C Products': np.int64(4261)}

# %%
plot_top_products(inventory)

# %%
plot_abc(inventory)

# %%
inventory.to_csv(
    PROJECT_ROOT/"data"/"processed"/"inventory_optimization.csv",
    index=False
)

print("Inventory Optimization Completed Successfully!")
# Out:
# Inventory Optimization Completed Successfully!
