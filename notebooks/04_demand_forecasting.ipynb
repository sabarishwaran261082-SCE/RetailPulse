# %%
import pandas as pd

# %%
import sys
from pathlib import Path

# Find project root (RetailPulse)
PROJECT_ROOT = Path.cwd().parent

# Add project root to Python path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd

from src.etl.ingest import load_data

from src.forecasting.preprocessing import *

from src.forecasting.prophet_model import *

from src.forecasting.evaluation import *

from src.forecasting.visualization import *

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Windows 10 Pro\OneDrive\Desktop\RETAILPULSE\notebooks

# %%
print(PROJECT_ROOT)
# Out:
# c:\Users\Windows 10 Pro\OneDrive\Desktop\RETAILPULSE

# %%
df = load_data("../data/processed/online_retail_processed.csv")
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  is_cancelled  \
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom         False
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom         False
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom         False
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom         False
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom         False
#
#    TotalPrice  Year  Month  Day DayOfWeek  Hour  Quarter  IsWeekend  \
# ...

# %%
monthly_sales = prepare_monthly_sales(df)

monthly_sales.head()
# Out:
#         Date       Sales
# 0 2009-12-31  796648.500
# 1 2010-01-31  622479.502
# 2 2010-02-28  531265.366
# 3 2010-03-31  763247.241
# 4 2010-04-30  641521.052

# %%
monthly_sales.tail()
# Out:
#          Date        Sales
# 20 2011-08-31   703510.580
# 21 2011-09-30  1017596.682
# 22 2011-10-31  1069368.230
# 23 2011-11-30  1456145.800
# 24 2011-12-31   432719.060

# %%
monthly_sales.shape
# Out:
# (25, 2)

# %% [markdown]
# prophet_df = prepare_prophet_data(
#     monthly_sales
# )
#
# prophet_df.head()

# %%
prophet_df = prepare_prophet_data(
    monthly_sales
)

prophet_df.head()
# Out:
#           ds           y
# 0 2009-12-31  796648.500
# 1 2010-01-31  622479.502
# 2 2010-02-28  531265.366
# 3 2010-03-31  763247.241
# 4 2010-04-30  641521.052

# %%
model = train_prophet(
    prophet_df
)
# Out:
# 21:02:49 - cmdstanpy - INFO - Chain [1] start processing
# 21:02:50 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast = forecast_sales(
    model,
    periods=12
)

# %%
forecast.head()
# Out:
#           ds          trend     yhat_lower     yhat_upper    trend_lower  \
# 0 2009-12-31  752254.210490  775723.462013  882172.535336  752254.210490
# 1 2010-01-31  751412.842402  525428.872008  626094.750166  751412.842402
# 2 2010-02-28  750652.897042  432190.908493  525928.940408  750652.897042
# 3 2010-03-31  749811.528871  674091.752422  776614.577863  749811.528871
# 4 2010-04-30  748997.301656  576117.414955  677819.307942  748997.301656
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  752254.210490    75265.965445          75265.965445          75265.965445
# 1  751412.842402  -177711.813803        -177711.813803        -177711.813803
# 2  750652.897042  -272388.410589        -272388.410589        -272388.410589
# 3  749811.528871   -22905.680807         -22905.680807         -22905.680807
# 4  748997.301656  -122073.274873        -122073.274873        -122073.274873
#
# ...

# %%
forecast.tail()
# Out:
#            ds          trend    yhat_lower    yhat_upper    trend_lower  \
# 32 2012-08-31  730373.024532  7.126890e+05  8.104917e+05  730154.149213
# 33 2012-09-30  729752.407072  6.232673e+05  7.251363e+05  729483.044421
# 34 2012-10-31  729111.102362  1.108285e+06  1.212676e+06  728801.220036
# 35 2012-11-30  728490.484902  1.230766e+06  1.326349e+06  728130.230244
# 36 2012-12-31  727849.180193  9.151815e+05  1.014008e+06  727439.784774
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 32  730576.426139    31613.244663          31613.244663          31613.244663
# 33  729999.367932   -54480.848806         -54480.848806         -54480.848806
# 34  729409.656971   431044.347576         431044.347576         431044.347576
# 35  728840.653568   546452.944708         546452.944708         546452.944708
# 36  728246.072977   235767.354619         235767.354619         235767.354619
#
# ...

# %%
forecast_plot(
    forecast
).show()

# %%
forecast[
    ["ds","yhat"]
].tail(12)
# Out:
#            ds          yhat
# 25 2012-01-31  6.449872e+05
# 26 2012-02-29  2.983277e+05
# 27 2012-03-31  7.023384e+05
# 28 2012-04-30  8.355483e+05
# 29 2012-05-31  4.183459e+05
# 30 2012-06-30  7.703967e+05
# 31 2012-07-31  6.726332e+05
# 32 2012-08-31  7.619863e+05
# 33 2012-09-30  6.752716e+05
# 34 2012-10-31  1.160155e+06
# 35 2012-11-30  1.274943e+06
# 36 2012-12-31  9.636165e+05

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd()

while PROJECT_ROOT.name != "RETAILPULSE":
    PROJECT_ROOT = PROJECT_ROOT.parent

output_dir = PROJECT_ROOT / "data" / "processed"
output_dir.mkdir(parents=True, exist_ok=True)

forecast.to_csv(
    output_dir / "sales_forecast.csv",
    index=False
)

print("Forecast Saved Successfully!")
# Out:
# Forecast Saved Successfully!

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.21.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

print("TensorFlow is working!")
# Out:
# TensorFlow is working!

# %%
from src.forecasting.lstm_model import *

import numpy as np
import pandas as pd

# %%
from importlib import reload
import src.forecasting.preprocessing as preprocessing

reload(preprocessing)

from src.forecasting.preprocessing import *

# %%
scaled_data, scaler = prepare_lstm_data(monthly_sales)

print(scaled_data.shape)
# Out:
# (25, 1)

# %%
X, y = create_sequences(
    scaled_data,
    sequence_length=12
)

print("X Shape:", X.shape)
print("y Shape:", y.shape)
# Out:
# X Shape: (13, 12, 1)
# y Shape: (13, 1)

# %%
model = build_lstm_model(
    (X.shape[1], X.shape[2])
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\Windows 10 Pro\OneDrive\Desktop\RETAILPULSE\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
history = train_lstm(
    model,
    X,
    y,
    epochs=100,
    batch_size=4
)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.1784
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1515
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1339
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1211
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1081
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0963
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0840
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0758
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0738
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0719
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0724
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0726
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0718
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0726
# Epoch 15/100
# ...

# %%
predictions = predict_lstm(
    model,
    X
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step

# %%
predicted_sales = scaler.inverse_transform(predictions)

actual_sales = scaler.inverse_transform(y)

predicted_sales[:5]
# Out:
# array([[669015.44],
#        [608013.06],
#        [610010.9 ],
#        [629851.7 ],
#        [620879.4 ]], dtype=float32)

# %%
comparison = pd.DataFrame({
    "Actual": actual_sales.flatten(),
    "Predicted": predicted_sales.flatten()
})

comparison.head()
# Out:
#        Actual    Predicted
# 0  746723.610  669015.4375
# 1  558448.560  608013.0625
# 2  497026.410  610010.8750
# 3  682013.980  629851.6875
# 4  492367.841  620879.3750

# %%
metrics = evaluate(
    comparison["Actual"],
    comparison["Predicted"]
)

metrics
# Out:
# {'MAE': 94491.86,
#  'RMSE': np.float64(113294.9),
#  'MAPE': np.float64(14.67),
#  'R2': 0.83}

# %%
import plotly.express as px

fig = px.line(
    comparison,
    title="LSTM: Actual vs Predicted Sales"
)

fig.show()

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

output_dir = PROJECT_ROOT / "data" / "processed"
output_dir.mkdir(parents=True, exist_ok=True)

comparison.to_csv(
    output_dir / "lstm_forecast.csv",
    index=False
)

print("LSTM Forecast Saved Successfully!")
# Out:
# LSTM Forecast Saved Successfully!
